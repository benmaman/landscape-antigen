# %%
import pickle
import pandas as pd
import numpy as np

# %%
# To load a pickle file
with open('serum_IgA_21_05_2024.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data.keys()
# Out:
# dict_keys(['exp_dates', 'arr_df', 'bg_df', 'protein_df', 'samples_df', 'NA_subtype_dict', 'HA_subtype_dict', 'subtype_names', 'internal_proteins', 'antigens', 'individuals_not_included', 'arr_summary_stats_proteins', 'selected_threshold_proteins'])

# %%
pd.DataFrame(data["arr_df"].columns).to_csv("list_of_antigen_hertz.csv")

# %%
data["arr_df"].to_csv("titer_values.csv")
